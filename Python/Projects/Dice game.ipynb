# %%
#importing the module to generate random dice values
import random

print("This is a dice game")

#taking the user input
response = input("\nDo you want to roll the dice: y-Yes n-No  ").lower()

def dice_game(res):
    
    if res == "n":
        print("Bye!!")
        
    elif res == "y":
        number = random.randint(1,6)
        if number == 1:
            print("----------")
            print("|        |")
            print("|    O   |")
            print("|        |")
            print("----------")
        if number == 2:
            print("----------")
            print("|        |")
            print("| O    O |")
            print("|        |")
            print("----------")
        if number == 3:
            print("----------")
            print("|    O   |")
            print("|    O   |")
            print("|    O   |")
            print("----------")
        if number == 4:
            print("----------")
            print("| O    O |")
            print("|        |")
            print("| O    O |")
            print("----------")
        if number == 5:
            print("----------")
            print("| O    O |")
            print("|    O   |")
            print("| O    O |")
            print("----------")
        if number == 6:
            print("----------")
            print("| O    O |")
            print("| O    O |")
            print("| O    O |")
            print("----------")
                
        res = input("\nDo you want to roll the dice again: y-Yes n-No  ").lower()
            
        if res == "y":
            dice_game(res)
        
        elif res == "n":
            print("Bye!!")
            
        else:
            print("Invalid key, press only y or n")
            res = input("\nDo you want to roll the dice again: y-Yes n-No  ").lower()
            dice_game(res)
    
    elif res != "n" or "y":
        print("Invalid key, press only y or n")
        response = input("\nDo you want to roll the dice: y-Yes n-No  ").lower()
        dice_game(response)
        
dice_game(response)
# Out:
# This is a dice game
#
# Do you want to roll the dice: y-Yes n-No  y
# ----------
# | O    O |
# |        |
# | O    O |
# ----------
#
# Do you want to roll the dice again: y-Yes n-No  n
# Bye!!
