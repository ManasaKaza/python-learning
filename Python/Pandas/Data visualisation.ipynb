# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = sns.load_dataset('tips')
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2 = pd.read_csv('204.ece.csv')
df2
# Out:
#       Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0           ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1           ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2           ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3           ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4           ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
# ...                ...      ...         ...         ...    ...      ...
# 16025       ECTQ.S4AXP  2018.03        47.2         NaN      F  Percent
# 16026       ECTQ.S4AXP  2018.06        48.6         NaN      F  Percent
# 16027       ECTQ.S4AXP  2018.09        48.2         NaN      F  Percent
# 16028       ECTQ.S4AXP  2018.12        46.6         NaN      F  Percent
# 16029       ECTQ.S4AXP  2019.03        45.8         NaN      F  Percent
#
#        Magnitude                                        Subject  \
# 0              6  Electronic Card Transactions (ANZSIC06) - ECT
# 1              6  Electronic Card Transactions (ANZSIC06) - ECT
# 2              6  Electronic Card Transactions (ANZSIC06) - ECT
# 3              6  Electronic Card Transactions (ANZSIC06) - ECT
# 4              6  Electronic Card Transactions (ANZSIC06) - ECT
# ...          ...                                            ...
# 16025          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16026          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16027          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16028          0  Electronic Card Transactions (ANZSIC06) - ECT
# 16029          0  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                    Group Series_title_1  \
# 0      Total values - Electronic card transactions A/...         Actual
# 1      Total values - Electronic card transactions A/...         Actual
# 2      Total values - Electronic card transactions A/...         Actual
# 3      Total values - Electronic card transactions A/...         Actual
# 4      Total values - Electronic card transactions A/...         Actual
# ...                                                  ...            ...
# 16025  Electronic card transactions by mean and propo...         Actual
# 16026  Electronic card transactions by mean and propo...         Actual
# 16027  Electronic card transactions by mean and propo...         Actual
# 16028  Electronic card transactions by mean and propo...         Actual
# 16029  Electronic card transactions by mean and propo...         Actual
#
#                                           Series_title_2  Series_title_3  \
# 0                                   RTS total industries             NaN
# 1                                   RTS total industries             NaN
# 2                                   RTS total industries             NaN
# 3                                   RTS total industries             NaN
# 4                                   RTS total industries             NaN
# ...                                                  ...             ...
# 16025  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16026  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16027  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16028  Debit card usage as a proportion of total ECT ...  Proportion (%)
# 16029  Debit card usage as a proportion of total ECT ...  Proportion (%)
#
#        Series_title_4  Series_title_5
# 0                 NaN             NaN
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# ...               ...             ...
# 16025             NaN             NaN
# 16026             NaN             NaN
# 16027             NaN             NaN
# 16028             NaN             NaN
# 16029             NaN             NaN
#
# [16030 rows x 14 columns]

# %%
x1 = np.random.rand(100,5)
x1
# Out:
# array([[4.13888844e-01, 4.94433958e-01, 9.56849007e-01, 9.08645533e-01,
#         2.27354147e-01],
#        [7.63935445e-01, 3.46325941e-03, 7.67149654e-01, 1.98429911e-01,
#         7.85845914e-01],
#        [5.92843604e-01, 8.41924113e-02, 6.83796858e-01, 2.96563062e-01,
#        [7.48750324e-01, 9.23345893e-01, 5.84436555e-01, 4.96893044e-02,
#         9.81415288e-02],
#        [7.70305052e-01, 3.96958908e-01, 3.69282480e-01, 9.78321566e-01,
#         5.29420250e-01],
#        [6.10440309e-01, 5.74488697e-01, 2.72370589e-01, 1.22112989e-01,
#         8.38399333e-01],
#        [8.85781599e-01, 2.47738663e-01, 7.75739919e-01, 1.06791069e-01,
#         4.82525107e-01],
#        [8.16176315e-01, 1.80328541e-01, 3.93459268e-01, 7.50643492e-01,
#         7.26968805e-01],
#        [8.95283114e-01, 7.29584577e-02, 9.38679851e-01, 6.40428020e-01,
#         2.33388297e-01],
#        [9.44079316e-01, 7.19534775e-01, 1.45672307e-01, 1.60795007e-01,
#         4.40868080e-01],
#        [5.13211886e-01, 9.42978606e-01, 5.14102037e-01, 8.36080486e-01,
#         6.50734824e-01],
#        [5.91242205e-01, 5.21286473e-01, 9.10751777e-01, 4.54189059e-01,
#         8.79512218e-01],
#        [7.61910424e-01, 4.22944506e-01, 2.75130205e-01, 6.08211591e-01,
#         1.90268441e-01],
#        [5.50401219e-01, 8.50835487e-01, 3.80930465e-01, 3.67548945e-01,
#         7.51904201e-01],
#        [3.37662956e-01, 5.67276867e-01, 5.20411820e-01, 6.40538478e-01,
#         6.38878019e-01],
#        [3.77172230e-02, 2.07769758e-01, 4.04888975e-01, 9.64332739e-02,
#         8.00011395e-01],
#        [9.08940080e-01, 5.06641571e-01, 3.88306103e-01, 8.74553862e-01,
#         9.83632736e-02],
#        [9.63143331e-01, 7.77371474e-01, 3.39791617e-01, 8.42524892e-01,
#         2.53842725e-01]])

# %%
x2 = np.random.rand(10,5)
x2
# Out:
# array([[0.92737939, 0.79076797, 0.81397123, 0.80604323, 0.79971124],
#        [0.36766704, 0.42240687, 0.93253299, 0.9292173 , 0.39878902],
#        [0.39019823, 0.306825  , 0.87618516, 0.26486617, 0.55285742],
#        [0.98016268, 0.43405523, 0.26328861, 0.93606892, 0.21086971],
#        [0.21205259, 0.95850496, 0.72272004, 0.91997668, 0.95006527],
#        [0.49414281, 0.08868616, 0.22637321, 0.74334935, 0.36624321],
#        [0.14182924, 0.99515268, 0.70398542, 0.4844255 , 0.64442129],
#        [0.92266957, 0.64123844, 0.22405029, 0.40957208, 0.80989811],
#        [0.4223288 , 0.17633327, 0.47117538, 0.4612125 , 0.72516227],
#        [0.37844703, 0.15414528, 0.13559284, 0.49926428, 0.05576462]])

# %%
df3 = pd.DataFrame(x1, columns = ['a','b','c','d','e'])
df3
# Out:
#            a         b         c         d         e
# 0   0.413889  0.494434  0.956849  0.908646  0.227354
# 1   0.763935  0.003463  0.767150  0.198430  0.785846
# 2   0.592844  0.084192  0.683797  0.296563  0.400217
# 3   0.081715  0.031453  0.471521  0.228330  0.421823
# 4   0.295992  0.848019  0.137794  0.681037  0.014343
# ..       ...       ...       ...       ...       ...
# 95  0.550401  0.850835  0.380930  0.367549  0.751904
# 96  0.337663  0.567277  0.520412  0.640538  0.638878
# 97  0.037717  0.207770  0.404889  0.096433  0.800011
# 98  0.908940  0.506642  0.388306  0.874554  0.098363
# 99  0.963143  0.777371  0.339792  0.842525  0.253843
#
# [100 rows x 5 columns]

# %%
df4 = pd.DataFrame(x2, columns = ['a','b','c','d','e'])
df4
# Out:
#           a         b         c         d         e
# 0  0.927379  0.790768  0.813971  0.806043  0.799711
# 1  0.367667  0.422407  0.932533  0.929217  0.398789
# 2  0.390198  0.306825  0.876185  0.264866  0.552857
# 3  0.980163  0.434055  0.263289  0.936069  0.210870
# 4  0.212053  0.958505  0.722720  0.919977  0.950065
# 5  0.494143  0.088686  0.226373  0.743349  0.366243
# 6  0.141829  0.995153  0.703985  0.484425  0.644421
# 7  0.922670  0.641238  0.224050  0.409572  0.809898
# 8  0.422329  0.176333  0.471175  0.461213  0.725162
# 9  0.378447  0.154145  0.135593  0.499264  0.055765

# %% [markdown]
# # point plots

# %%
df3.plot.scatter(x = 'a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df4.plot.scatter(x = 'a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df1.plot.scatter(x = 'total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=df1, x="total_bill", y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Line plots

# %%
df3.plot.line()
# Out:
# <AxesSubplot:>

# %%
df3['a'].plot.line()
# Out:
# <AxesSubplot:>

# %%
df4.plot.line()
# Out:
# <AxesSubplot:>

# %%
df4['a'].plot.line()
# Out:
# <AxesSubplot:>

# %%
df4.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# C:\Users\DELL\anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py:203: RuntimeWarning: All-NaN slice encountered
#   sample_range = np.nanmax(y) - np.nanmin(y)
# C:\Users\DELL\anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py:205: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(y) - 0.5 * sample_range,
# C:\Users\DELL\anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py:206: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(y) + 0.5 * sample_range,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37484\2798605528.py in <module>
# ----> 1 df2.plot.kde()
#
# ~\anaconda\lib\site-packages\pandas\plotting\_core.py in kde(self, bw_method, ind, **kwargs)
#    1480             >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1481         """
# -> 1482         return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#    1483
#    1484     density = kde
#
# ~\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     450         self._compute_plot_data()
#     451         self._setup_subplots()
# --> 452         self._make_plot()
#     453         self._add_table()
#     454         self._make_legend()
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py in _make_plot(self)
#     152                 kwds["weights"] = weights[:, i]
#     153
# --> 154             artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     155
#     156             # when by is applied, show title for subplots to know which group it is
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\hist.py in _plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     233
#     234         y = remove_na_arraylike(y)
# --> 235         gkde = gaussian_kde(y, bw_method=bw_method)
#     236
#     237         y = gkde.evaluate(ind)
#
# ~\anaconda\lib\site-packages\scipy\stats\_kde.py in __init__(self, dataset, bw_method, weights)
#     192         self.dataset = atleast_2d(asarray(dataset))
#     193         if not self.dataset.size > 1:
# --> 194             raise ValueError("`dataset` input should have multiple elements.")
#     195
#     196         self.d, self.n = self.dataset.shape
#
# ValueError: `dataset` input should have multiple elements.

# %%
df4.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Distribution plots

# %%
df4.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.hist()
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'b'}>],
#        [<AxesSubplot:title={'center':'c'}>,
#         <AxesSubplot:title={'center':'d'}>],
#        [<AxesSubplot:title={'center':'e'}>, <AxesSubplot:>]], dtype=object)

# %%
df4['a'].hist()
# Out:
# <AxesSubplot:>

# %%
df4['a'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4[['a','e']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'a'}>,
#         <AxesSubplot:title={'center':'e'}>]], dtype=object)

# %%
df4[['a','e']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df4.plot.area()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37484\3911305024.py in <module>
# ----> 1 df4.plot.area()
#
# ~\anaconda\lib\site-packages\pandas\plotting\_core.py in area(self, x, y, **kwargs)
#    1555             >>> ax = df.plot.area(x='day')
#    1556         """
# -> 1557         return self(kind="area", x=x, y=y, **kwargs)
#    1558
#    1559     def pie(self, **kwargs) -> PlotAccessor:
#
# ~\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     450         self._compute_plot_data()
#     451         self._setup_subplots()
# --> 452         self._make_plot()
#     453         self._add_table()
#     454         self._make_legend()
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1380             kwds["label"] = label
#    1381
# -> 1382             newlines = plotf(
#    1383                 ax,
#    1384                 x,
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1576             kwds["color"] = lines[0].get_color()
#    1577
# -> 1578         rect = ax.fill_between(xdata, start, y_values, **kwds)
#    1579         cls._update_stacker(ax, stacking_id, y)
#    1580
#
# ~\anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda\lib\site-packages\matplotlib\axes\_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5243     def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5244                      step=None, **kwargs):
# -> 5245         return self._fill_between_x_or_y(
#    5246             "x", x, y1, y2,
#    5247             where=where, interpolate=interpolate, step=step, **kwargs)
#
# ~\anaconda\lib\site-packages\matplotlib\axes\_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5171
#    5172         polys = []
# -> 5173         for idx0, idx1 in cbook.contiguous_regions(where):
#    5174             indslice = ind[idx0:idx1]
#    5175             dep1slice = dep1[idx0:idx1]
#
# ~\anaconda\lib\site-packages\matplotlib\cbook\__init__.py in contiguous_regions(mask)
#    1260
#    1261     # Find the indices of region changes, and correct offset
# -> 1262     idx, = np.nonzero(mask[:-1] != mask[1:])
#    1263     idx += 1
#    1264
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
df2.plot.area(alpha = 0.5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5056\4138710419.py in <module>
# ----> 1 df4.plot.area(alpha = 0.5)
#
# ~\anaconda\lib\site-packages\pandas\plotting\_core.py in area(self, x, y, **kwargs)
#    1555             >>> ax = df.plot.area(x='day')
#    1556         """
# -> 1557         return self(kind="area", x=x, y=y, **kwargs)
#    1558
#    1559     def pie(self, **kwargs) -> PlotAccessor:
#
# ~\anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     450         self._compute_plot_data()
#     451         self._setup_subplots()
# --> 452         self._make_plot()
#     453         self._add_table()
#     454         self._make_legend()
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1380             kwds["label"] = label
#    1381
# -> 1382             newlines = plotf(
#    1383                 ax,
#    1384                 x,
#
# ~\anaconda\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1576             kwds["color"] = lines[0].get_color()
#    1577
# -> 1578         rect = ax.fill_between(xdata, start, y_values, **kwds)
#    1579         cls._update_stacker(ax, stacking_id, y)
#    1580
#
# ~\anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda\lib\site-packages\matplotlib\axes\_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5243     def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5244                      step=None, **kwargs):
# -> 5245         return self._fill_between_x_or_y(
#    5246             "x", x, y1, y2,
#    5247             where=where, interpolate=interpolate, step=step, **kwargs)
#
# ~\anaconda\lib\site-packages\matplotlib\axes\_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5171
#    5172         polys = []
# -> 5173         for idx0, idx1 in cbook.contiguous_regions(where):
#    5174             indslice = ind[idx0:idx1]
#    5175             dep1slice = dep1[idx0:idx1]
#
# ~\anaconda\lib\site-packages\matplotlib\cbook\__init__.py in contiguous_regions(mask)
#    1260
#    1261     # Find the indices of region changes, and correct offset
# -> 1262     idx, = np.nonzero(mask[:-1] != mask[1:])
#    1263     idx += 1
#    1264
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed

# %%
df4.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4.plot.box()
# Out:
# <AxesSubplot:>

# %%
df4['a'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df1.plot.hexbin(x='total_bill',y='tip',gridsize=10,cmap='cool')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# import numpy as np

# # Set a seed value
# np.random.seed(42)

# # Generate some random numbers
# random_numbers = np.random.rand(5)

# print(random_numbers)
